# %% [markdown]
# # Business Case :- RiceLeaf Disease Detection

# %% [markdown]
# ### Problem Statement
#
# ***Task 1 :-*** To prepare a complete data analysis report on the given data.
#
# ***Task 2 :-*** To create a model which can classify the three major attacking diseases of rice plants like leaf blast, bacterial blight and brown spot.
#
# ***Task 3 :-*** Analyze various techniques like Data Augmentation, etc and create a
# report on that.

# %% [markdown]
# ### Note:-
# The practice of minimizing disease in crops aims to boost both the quantity and quality of harvest yields. This system assists farmers in making informed decisions, which ultimately enhances productivity, reduces environmental impact, and improves livelihoods in rice-growing regions around the globe.

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
IMAGE_SIZE=256
BATCH_SIZE=10
channels=3
epochs = 100

# %% [markdown]
# # Importing data into tensorflow dataset object

# %%
import os
print(os.listdir(os.getcwd()))
# Out:
# ['.DS_Store', 'Rice leaf disease prediction (2).ipynb', 'Bacterial leaf blight', '.ipynb_checkpoints', 'rice leaf final.ipynb', 'Leaf smut', 'Brown spot']

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    '.',  # Use '.' to refer to the current working directory
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 119 files belonging to 3 classes.

# %% [markdown]
# # Domain analysis and Data Information
#
#
# Rice is one of the most important staple crops worldwide, providing sustenance to over half of the world's population. However, rice plants are vulnerable to several diseases that can severely impact the yield and quality of rice production. Some of the major rice diseases that affect rice plants include bacterial leaf blight, brown spot, and leaf smut.
# This dataset contains 120 jpg images of disease-infected rice leaves. The images are grouped into 3 classes based on the type of disease. There are 40 images in each class.
#
# Classes :
#
# ● Leaf smut ● Brown spot ● Bacterial leaf blight
#
# Leaf smut caused by the fungus Entyloma oryzae, is a relatively less common rice disease. The symptoms of leaf smut include the formation of small, round, and reddish-brown spots on the leaves. These spots later turn black and produce powdery spores. Although leaf smut does not usually cause significant yield losses, it can affect the quality of rice grains by reducing their weight and size .
#
# Brown spot, caused by the fungus Cochliobolus miyabeanus, is another major rice disease that can cause significant yield losses. The disease is characterized by small, oval to elliptical spots on the leaves, which turn brown with a yellow halo. In severe cases, the spots can coalesce and cause the leaves to wither and die. Brown spot can also affect the panicles, leading to a reduction in grain quality and yield .
#
# Bacterial leaf blight, caused by the bacterium Xanthomonas oryzae pv. oryzae, is a serious disease that can cause extensive damage to rice plants. The symptoms of bacterial leaf blight include water-soaked lesions on the leaves, which later turn brown and dry up. In severe cases, the disease can cause wilting and death of the plant, leading to a significant reduction in crop yield .

# %%
#class names
class_names = dataset.class_names
class_names
# Out:
# ['Bacterial leaf blight', 'Brown spot', 'Leaf smut']

# %%
#total batches
len(dataset)
# Out:
# 12

# %%
for image_batch,label_batch in dataset.take(1):
    print(image_batch.shape)
    print(label_batch.numpy())
# Out:
# (10, 256, 256, 3)
# [0 0 2 2 1 1 2 2 2 0]

# %% [markdown]
# # Observations
# Each element in the dataset is a tuple. First element is a batch of 10 elements of images. Second element is a batch of 10 elements of class labels

# %% [markdown]
# ## Data Visualiztion

# %%
#create a new figure with height and width a square figure with both dimensions equal to 10 inches.
plt.figure(figsize=(25,20))                
for image_batch,label_batch in dataset.take(1):#contains a batch of images, and label_batch contains corresponding labels extract one batch from one dataset.
    for i in range(6): #first 6 images
        ax = plt.subplot(3,3,i+1)# creates a subpolt in number form.
        plt.imshow(image_batch[i].numpy().astype('uint8'))#converts it to an unsigned 8-bit integer format, which is suitable for displaying images.
        plt.title(class_names[label_batch[i]])# gives the class names of the image.
        plt.axis('off')

# %% [markdown]
# # Creating function to split the data for training, testing and validation.
# Dividing dataset into 3 parts. Namely:
#
# Training: Dataset to be used while training
#
# Validation: Dataset to be tested against while training
#
# Test: Dataset to be tested against after we trained a model

# %%
def get_prediction (ds,train_split = 0.8,test_split = 0.1, valid_split = 0.1 ,shuffle_size=10000,shuffle=True):
    ds_size = len(ds)
    if shuffle:
        ds = ds.shuffle(shuffle_size,seed=12)


    train_size = int(train_split * ds_size)
    valid_size = int(valid_split * ds_size)

    train_data = ds.take(train_size)
    valid_data = ds.skip(train_size).take(valid_size)
    test_data = ds.skip(train_size).skip(valid_size)

    return train_data,valid_data,test_data

train_data,valid_data,test_data = get_prediction(dataset)

# %%
len(train_data)
# Out:
# 9

# %%
len(valid_data)
# Out:
# 1

# %%
len(test_data)
# Out:
# 2

# %% [markdown]
# # Chache, shuffle and prefetch the dataset
#
# Catche -
#
# Instead of recomputing these values for each training iteration, the CNN can access and reuse them, which significantly speeds up training. This is especially helpful in CNNs where data augmentation or complex preprocessing is involved.
#
# Prefetch -
#
# During CNN training, there are often periods where the model is computing gradients while waiting for the next batch of data to load. Prefetching allows us to start loading the next batch in the background while the model is training on the current batch. This overlapping of operations helps keep the GPU or CPU busy and can lead to faster training times.
#
# Shuffle -
#
# If we feed the CNN consecutive batches of data that are highly correlated (e.g., all images of one class followed by another), the model may learn patterns based on this order, which can lead to poor generalization. Shuffling ensures that each batch contains a random mix of samples from different classes, making the training process more robust.

# %%
train_data = train_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
valid_data = valid_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_data = test_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# # Creating a Layer for Resizing and Normalization
#
# Before we feed our images to network, we should be resizing it to the desired size. Moreover, to improve model performance, we should normalize the image pixel value (keeping them in range 0 and 1 by dividing by 256). This should happen while training as well as inference. Hence we can add that as a layer in our Sequential Model.
#
# You might be thinking why do we need to resize (256,256) image to again (256,256). You are right we don't need to but this will be useful when we are done with the training and start using the model for predictions. At that time somone can supply an image that is not (256,256) and this layer will resize it

# %%
import tensorflow as tf
print(tf.__version__)

import keras
print(keras.__version__)
# Out:
# 2.18.0
# 3.8.0

# %%
#preprocessing
import tensorflow as tf
from tensorflow.keras import layers

# Define the preprocessing pipeline
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.Rescaling(1.0 / 255)
])

# %% [markdown]
# # Data Augmentation
#
# Data augmentation is a technique used to increase the size and diversity of a dataset by applying various transformations to the existing data. This technique has become an essential tool in computer vision and image processing tasks, such as object recognition and classification, due to its ability to enhance the generalization ability of machine learning models and prevent overfitting.
#
# In the context of our rice leaf disease image classification project, data augmentation can play a crucial role in improving the performance and robustness of our model. By generating new images with different variations such as rotations, flips, zooms, and other transformations, we can increase the diversity of our dataset and provide our model with more examples to learn from, which can lead to better classification accuracy and robustness to variations in the real-world data.

# %%
import tensorflow as tf
from tensorflow.keras import layers

# Define the data augmentation pipeline
data_aug = tf.keras.Sequential([
    layers.RandomFlip('horizontal_and_vertical'),
    layers.RandomRotation(0.2)
])

# %%
# Applying Data Augmentation on train dataset

train_data = train_data.map(
    lambda x, y: (data_aug(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# # Model Architecture
#
# Here use a CNN coupled with a Softmax Activation in the output layerand also add the initial layers for Resizing, Normalization and Data Augmentation.

# %%
input_shape = (BATCH_SIZE,IMAGE_SIZE,IMAGE_SIZE,channels)#Specifies the shape of the input data 
n_classes = 3 #the number of classes in the classification

model = models.Sequential([
    resize_and_rescale,
    data_aug,
    layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),#convolutional layer with 32 filters of size with ReLU activation function.
    layers.MaxPool2D((2,2)),   #Max pooling helps in reducing the spatial dimensions of the representation of no.fo parameters.
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPool2D(2,2),
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPool2D(2,2),
    layers.Flatten(),# flatten is input tensor in to  1D array and it is necessary for conectionfor layers before feeding.
    layers.Dense(64,activation='relu'),#fully connected layer with 64 neurons and ReLU activation function.
    layers.Dense(n_classes, activation='softmax')#n_classes(no.of classes) ,Softmax is multi-class classification to output probabilities for each class.
])

model.build(input_shape=input_shape)

# %%
#Architecture
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_3 (Sequential)       │ (10, 256, 256, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_4 (Sequential)       │ (10, 256, 256, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (10, 254, 254, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (10, 127, 127, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (10, 125, 125, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (10, 62, 62, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (10, 60, 60, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (10, 30, 30, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (10, 28, 28, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (10, 14, 14, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (10, 12, 12, 32)       │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (10, 6, 6, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (10, 1152)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (10, 64)               │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (10, 3)                │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 185,699 (725.39 KB)
#  Trainable params: 185,699 (725.39 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Compiling the Model
#
# We use adam Optimizer, SparseCategoricalCrossentropy for losses, accuracy as a metric.

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(train_data,epochs=epochs,batch_size=BATCH_SIZE,verbose=1,
         validation_data=valid_data)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.3248 - loss: 1.1159 - val_accuracy: 0.5000 - val_loss: 1.0659
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.3181 - loss: 1.1087 - val_accuracy: 0.5000 - val_loss: 1.0726
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - accuracy: 0.2751 - loss: 1.1080 - val_accuracy: 0.5000 - val_loss: 1.0828
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.3733 - loss: 1.0990 - val_accuracy: 0.5000 - val_loss: 1.0625
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - accuracy: 0.3390 - loss: 1.1052 - val_accuracy: 0.5000 - val_loss: 1.0853
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.3243 - loss: 1.0997 - val_accuracy: 0.5000 - val_loss: 1.0847
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - accuracy: 0.3037 - loss: 1.0974 - val_accuracy: 0.5000 - val_loss: 1.0710
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - accuracy: 0.4274 - loss: 1.0747 - val_accuracy: 0.5000 - val_loss: 1.0581
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - accuracy: 0.4241 - loss: 1.0827 - val_accuracy: 0.4000 - val_loss: 1.0950
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.4662 - loss: 1.0546 - val_accuracy: 0.4000 - val_loss: 0.9930
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.4574 - loss: 1.0474 - val_accuracy: 0.6000 - val_loss: 1.0416
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.4930 - loss: 1.0122 - val_accuracy: 0.7000 - val_loss: 0.9217
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.6636 - loss: 0.8736 - val_accuracy: 0.6000 - val_loss: 0.8434
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.6095 - loss: 0.8827 - val_accuracy: 0.7000 - val_loss: 0.9301
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.5856 - loss: 0.8958 - val_accuracy: 0.6000 - val_loss: 0.9581
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.4928 - loss: 1.0008 - val_accuracy: 0.7000 - val_loss: 0.9072
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.7281 - loss: 0.8817 - val_accuracy: 0.6000 - val_loss: 0.7530
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.4820 - loss: 0.9741 - val_accuracy: 0.7000 - val_loss: 0.8251
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.6830 - loss: 0.8305 - val_accuracy: 0.7000 - val_loss: 0.8469
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.6005 - loss: 0.8686 - val_accuracy: 0.7000 - val_loss: 0.7471
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.6979 - loss: 0.8211 - val_accuracy: 0.7000 - val_loss: 0.8446
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.7156 - loss: 0.7136 - val_accuracy: 0.8000 - val_loss: 0.7174
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.6247 - loss: 0.8680 - val_accuracy: 0.7000 - val_loss: 0.7148
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.6556 - loss: 0.8187 - val_accuracy: 0.7000 - val_loss: 0.6985
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - accuracy: 0.7836 - loss: 0.5904 - val_accuracy: 0.7000 - val_loss: 0.7324
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.7386 - loss: 0.6759 - val_accuracy: 0.7000 - val_loss: 0.7247
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 227ms/step - accuracy: 0.7038 - loss: 0.6672 - val_accuracy: 0.7000 - val_loss: 0.6834
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.7854 - loss: 0.6276 - val_accuracy: 0.7000 - val_loss: 0.7439
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.6507 - loss: 0.6986 - val_accuracy: 0.7000 - val_loss: 0.6876
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.7012 - loss: 0.6797 - val_accuracy: 0.5000 - val_loss: 0.9078
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.6339 - loss: 0.7138 - val_accuracy: 0.7000 - val_loss: 0.6948
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.7236 - loss: 0.6622 - val_accuracy: 0.7000 - val_loss: 0.6621
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.6296 - loss: 0.7142 - val_accuracy: 0.6000 - val_loss: 1.1622
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.6490 - loss: 0.8421 - val_accuracy: 0.6000 - val_loss: 0.9142
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.6891 - loss: 0.7156 - val_accuracy: 0.7000 - val_loss: 0.7675
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.6656 - loss: 0.7151 - val_accuracy: 0.7000 - val_loss: 0.6930
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.7892 - loss: 0.5240 - val_accuracy: 0.7000 - val_loss: 0.5715
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.8067 - loss: 0.4857 - val_accuracy: 0.8000 - val_loss: 0.4743
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.6921 - loss: 0.6051 - val_accuracy: 0.8000 - val_loss: 0.4120
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.7354 - loss: 0.5409 - val_accuracy: 0.7000 - val_loss: 0.6826
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.7928 - loss: 0.4797 - val_accuracy: 0.7000 - val_loss: 0.5028
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.7987 - loss: 0.4962 - val_accuracy: 0.7000 - val_loss: 0.5402
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.8046 - loss: 0.4641 - val_accuracy: 0.7000 - val_loss: 0.5187
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.8107 - loss: 0.4171 - val_accuracy: 0.8000 - val_loss: 0.5535
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.8261 - loss: 0.4759 - val_accuracy: 0.7000 - val_loss: 0.4235
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.8186 - loss: 0.4432 - val_accuracy: 0.8000 - val_loss: 0.4009
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - accuracy: 0.7299 - loss: 0.5428 - val_accuracy: 0.8000 - val_loss: 0.4263
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.7355 - loss: 0.5383 - val_accuracy: 0.7000 - val_loss: 0.4093
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.7266 - loss: 0.5186 - val_accuracy: 0.7000 - val_loss: 0.4182
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - accuracy: 0.8477 - loss: 0.4325 - val_accuracy: 0.8000 - val_loss: 0.3754
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.8244 - loss: 0.4880 - val_accuracy: 0.9000 - val_loss: 0.2987
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.8560 - loss: 0.3611 - val_accuracy: 0.9000 - val_loss: 0.2580
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8240 - loss: 0.3415 - val_accuracy: 0.9000 - val_loss: 0.2855
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.9162 - loss: 0.3185 - val_accuracy: 0.9000 - val_loss: 0.2767
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.9289 - loss: 0.2552 - val_accuracy: 0.8000 - val_loss: 0.4830
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.7378 - loss: 0.5502 - val_accuracy: 0.7000 - val_loss: 1.0112
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.7325 - loss: 0.5677 - val_accuracy: 0.8000 - val_loss: 0.4308
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.7792 - loss: 0.5528 - val_accuracy: 0.8000 - val_loss: 0.4996
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.7168 - loss: 0.5013 - val_accuracy: 0.9000 - val_loss: 0.4412
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.7568 - loss: 0.5471 - val_accuracy: 0.9000 - val_loss: 0.4316
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.8455 - loss: 0.3739 - val_accuracy: 0.8000 - val_loss: 0.8344
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - accuracy: 0.8303 - loss: 0.4312 - val_accuracy: 0.9000 - val_loss: 0.3305
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.9168 - loss: 0.2842 - val_accuracy: 0.8000 - val_loss: 0.3768
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.9392 - loss: 0.2365 - val_accuracy: 0.8000 - val_loss: 0.3196
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.8683 - loss: 0.3118 - val_accuracy: 0.9000 - val_loss: 0.2244
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 229ms/step - accuracy: 0.8550 - loss: 0.4194 - val_accuracy: 0.8000 - val_loss: 0.2455
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - accuracy: 0.8855 - loss: 0.2615 - val_accuracy: 0.8000 - val_loss: 0.8949
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.8225 - loss: 0.4954 - val_accuracy: 1.0000 - val_loss: 0.1622
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8701 - loss: 0.3258 - val_accuracy: 0.9000 - val_loss: 0.1471
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 218ms/step - accuracy: 0.8917 - loss: 0.2539 - val_accuracy: 0.9000 - val_loss: 0.2182
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.8829 - loss: 0.3034 - val_accuracy: 0.9000 - val_loss: 0.2510
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8065 - loss: 0.3303 - val_accuracy: 1.0000 - val_loss: 0.1406
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.8748 - loss: 0.2838 - val_accuracy: 0.9000 - val_loss: 0.1279
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.9010 - loss: 0.2894 - val_accuracy: 0.9000 - val_loss: 0.4741
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - accuracy: 0.8202 - loss: 0.3497 - val_accuracy: 1.0000 - val_loss: 0.1337
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.9483 - loss: 0.2147 - val_accuracy: 0.9000 - val_loss: 0.1595
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - accuracy: 0.8929 - loss: 0.2256 - val_accuracy: 0.9000 - val_loss: 0.1877
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - accuracy: 0.7887 - loss: 0.4888 - val_accuracy: 0.8000 - val_loss: 0.7033
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - accuracy: 0.9289 - loss: 0.2603 - val_accuracy: 0.9000 - val_loss: 0.3316
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - accuracy: 0.8901 - loss: 0.2795 - val_accuracy: 0.9000 - val_loss: 0.1924
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - accuracy: 0.9197 - loss: 0.2426 - val_accuracy: 0.8000 - val_loss: 0.2612
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.8833 - loss: 0.2856 - val_accuracy: 0.9000 - val_loss: 0.1379
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 218ms/step - accuracy: 0.8293 - loss: 0.4168 - val_accuracy: 0.9000 - val_loss: 0.3145
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - accuracy: 0.8373 - loss: 0.3485 - val_accuracy: 0.9000 - val_loss: 0.3514
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.8513 - loss: 0.3510 - val_accuracy: 1.0000 - val_loss: 0.1479
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.8974 - loss: 0.4211 - val_accuracy: 0.9000 - val_loss: 0.2954
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - accuracy: 0.8314 - loss: 0.4803 - val_accuracy: 1.0000 - val_loss: 0.2027
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.9101 - loss: 0.3452 - val_accuracy: 0.9000 - val_loss: 0.3185
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - accuracy: 0.8464 - loss: 0.3093 - val_accuracy: 0.9000 - val_loss: 0.2349
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - accuracy: 0.8941 - loss: 0.2840 - val_accuracy: 0.8000 - val_loss: 0.2600
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - accuracy: 0.9525 - loss: 0.2106 - val_accuracy: 0.9000 - val_loss: 0.1894
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.9511 - loss: 0.2288 - val_accuracy: 1.0000 - val_loss: 0.0687
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - accuracy: 0.8964 - loss: 0.2808 - val_accuracy: 1.0000 - val_loss: 0.0571
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - accuracy: 0.9413 - loss: 0.2051 - val_accuracy: 1.0000 - val_loss: 0.0840
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 240ms/step - accuracy: 0.8976 - loss: 0.2829 - val_accuracy: 1.0000 - val_loss: 0.0692
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 227ms/step - accuracy: 0.8945 - loss: 0.2222 - val_accuracy: 0.9000 - val_loss: 0.1763
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - accuracy: 0.9017 - loss: 0.2298 - val_accuracy: 0.9000 - val_loss: 0.1301
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 230ms/step - accuracy: 0.9259 - loss: 0.2144 - val_accuracy: 0.9000 - val_loss: 0.1150
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.9053 - loss: 0.2501 - val_accuracy: 0.8000 - val_loss: 0.3380
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 223ms/step - accuracy: 0.8595 - loss: 0.2908 - val_accuracy: 0.9000 - val_loss: 0.1435

# %%
score = model.evaluate(test_data)#the performance of a trained TensorFlow/Keras model on a test dataset.
score
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8000 - loss: 0.3523
# [0.3829491138458252, 0.800000011920929]

# %% [markdown]
# # Plotting the Accuracy and Loss Curves

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 100, 'steps': 9}

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(epochs), acc, label='Training Accuracy')
plt.plot(range(epochs), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(epochs), loss, label='Training Loss')
plt.plot(range(epochs), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Run prediction on a sample image

# %%
#prediction on sample
plt.figure(figsize=(10,10))
import numpy as np
for images_batch, labels_batch in test_data.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Bacterial leaf blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# predicted label: Bacterial leaf blight

# %% [markdown]
# # Creating a function for inference

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %% [markdown]
# # Prediction on few Sample Images

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_data.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class},\n Confidence: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2025-01-15 19:24:18.929300: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## Summary
# 1. The project involved building a deep learning model to classify images of rice leaf disease. The dataset contained images from 3 type of
# rice leaf disease namely bacterial bligh, brown spot, and leaf smut. The project was divided into several steps, including data exploration,
# data preprocessing, building and training deep learning models, and evaluating model performance.
#
# 2.
# During data exploration, we analyzed the dataset and visualized the images to get a better understanding of the data. We observed that the
# dataset was balanced, with an equal number of images for rice leaf diseases. We also noticed that the images were of different sizes
# and needed to be resized to a uniform size before being used for training. We have rescaled them to uniform size of 256 X 2sive hardware.

# %% [markdown]
# 3. For data preprocessing, We have normalized the training dataset . We used Keras' ImageDataGenerator to generate augmented images to increase the size of the dataset and reduce overfitting. We also resized the images and divided them into training, validation, and testing sets.
#
# 4. We built deep learning models by applying transfer learning technique, we trained model on augmented datasets and evaluated their performance using accuracy, loss, and time taken per epoch.

# %% [markdown]
# ## Problem Challenge -
#
# 1. Limited amount of data:
# - One of the biggest challenges in the project was the limited amount of data available for training the models. We had only 119 images from 3 classes. This could lead to overfitting, where the model memorizes the training data and does not generalize well to new data. To deal with this challenge, data augmentation techniques were used to artificially increase the size of the dataset. This helped to improve the performance of the models and reduce overfitting.
#
# 2. Complexity of deep learning models:
# - Deep learning models can be very complex and have a large number of parameters, which makes them difficult to train and optimize. To deal with this challenge, various techniques such as regularization, and early stopping were used to prevent overfitting and improve the performance of the models.
#
# 3. Hardware limitations:
# - Deep learning models require a lot of computational resources, especially when training on large datasets. This can be a challenge if we don't have access to powerful hardware. To deal with this challenge, cloud computing services such as Google Colab were used to train the models, which provided access to powerful GPUs without the need for expensive hardware.
